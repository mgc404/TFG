# %%
import os
from tensorflow.keras.utils import load_img
import matplotlib.pyplot as plt

# %%
img_path = os.path.join('Imatges\CelebA\Img\img_align_celeba\img_align_celeba',"000001.jpg")

# %%
plt.axis("off")
plt.imshow(load_img(img_path))
